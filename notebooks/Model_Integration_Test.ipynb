# %% [markdown]
# # Kronos Model Integration Test
#
# This notebook verifies the integration of the Kronos model strategy in a Colab environment.

# %%
# 1. Clone Repositories
import sys
import os
from getpass import getpass

if 'google.colab' in sys.modules:
    try:
        from google.colab import userdata
        token = userdata.get('GITHUB_TOKEN')
    except:
        token = None

    if not token:
        print("GitHub Token not found in userdata.")
        token = getpass("Please enter your GitHub Token: ")

    if token:
        repo_kronos = f"https://{token}@github.com/shiyu-coder/Kronos.git"
        repo_test = f"https://{token}@github.com/PavelPetrovich87/kronos_test.git"
    else:
        repo_kronos = "https://github.com/shiyu-coder/Kronos.git"
        repo_test = "https://github.com/PavelPetrovich87/kronos_test.git"

    if not os.path.exists('Kronos'):
        # !git clone {repo_kronos}
    
    if not os.path.exists('kronos_test'):
        # !git clone {repo_test}
    
    # %cd kronos_test
else:
    print("Not running in Colab. Skipping automatic clone.")
# Out:
# GitHub Token not found in userdata.
# Cloning into 'Kronos'...
# remote: Enumerating objects: 316, done.
# remote: Counting objects: 100% (201/201), done.
# remote: Compressing objects: 100% (72/72), done.
# remote: Total 316 (delta 143), reused 129 (delta 129), pack-reused 115 (from 2)
# Receiving objects: 100% (316/316), 6.24 MiB | 24.10 MiB/s, done.
# Resolving deltas: 100% (167/167), done.
# Cloning into 'kronos_test'...
# remote: Enumerating objects: 114, done.
# remote: Counting objects: 100% (114/114), done.
# remote: Compressing objects: 100% (85/85), done.
# remote: Total 114 (delta 21), reused 114 (delta 21), pack-reused 0 (from 0)
# Receiving objects: 100% (114/114), 98.89 KiB | 2.25 MiB/s, done.
# Resolving deltas: 100% (21/21), done.
# /content/kronos_test/kronos_test/kronos_test

# %%
# 2. Install Dependencies
# !pip install -r requirements.txt

# %%
# 3. Run Verification Script (Real Mode)
# This attempts to load the model (downloading from HF if needed) and generate signals.
# !python verify_quickstart.py --mode real
# Out:
# Loading data...
# Loading data from data/BTC-USD_1h.csv
# Initializing Strategy (Mode: real)...
# Adding Kronos path to sys.path: /content/kronos_test/kronos_test/Kronos
# Loading Kronos model: NeoQuasar/Kronos-small on cpu...
# Model loaded successfully.
# 100% 1/1 [00:00<00:00,  7.48it/s]
# Execution failed: DataFrame must contain 'prediction' column or Strategy must have a generic predictor.
# Traceback (most recent call last):
#   File "/content/kronos_test/kronos_test/kronos_test/verify_quickstart.py", line 62, in main
#     signals = strategy.generate_signals(df)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/kronos_test/kronos_test/kronos_test/lib/strategy.py", line 112, in generate_signals
#     raise ValueError("DataFrame must contain 'prediction' column or Strategy must have a generic predictor.")
# ValueError: DataFrame must contain 'prediction' column or Strategy must have a generic predictor.

# %%
# 4. Check Environment
import torch
print(f"CUDA Available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"Device: {torch.cuda.get_device_name(0)}")
# Out:
# CUDA Available: True
# Device: Tesla T4
